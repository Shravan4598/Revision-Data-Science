# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# Use the kagglehub client library to attach Kaggle resources like competitions, datasets, and models to your session
# Learn more about kagglehub: https://github.com/Kaggle/kagglehub/blob/main/README.md

import kagglehub
# kagglehub.dataset_download('<owner>/<dataset-slug>')
# Out:
# /kaggle/input/datasets/padmapriyatr/netflix-titles/netflix_titles.csv

# %% [markdown]
# # Importing Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Loading the data

# %%
df=pd.read_csv("/kaggle/input/datasets/padmapriyatr/netflix-titles/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %% [markdown]
# # Checking the shape of the data

# %%
df.shape
# Out:
# (8807, 12)

# %% [markdown]
# ### Key Insight
# - It has 8807 rows and 12 columns.

# %% [markdown]
# # Name of the columns

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %% [markdown]
# # Checking the datatype of the columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %% [markdown]
# ### Key Insights
# - director,cast,country,date_added,rating and duration has missing values
# - All columns are categorical except release_year.

# %% [markdown]
# # Checking Duplicate values

# %%
int(df.duplicated().sum())
# Out:
# 0

# %% [markdown]
# ### Key insight
# - It has no duplicate data

# %% [markdown]
# # Checking the missing values

# %%
int(df.isnull().sum().sum())
# Out:
# 4307

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %% [markdown]
# ### Key Insights
# - It has 4307 missing values
# - director  -->      2634
# - cast      -->       825
# - country     -->     831
# - date_added  -->      10
# - rating       -->      4
# - duration     -->   3

# %% [markdown]
# # Categorical Columns and Numerical Columns

# %%
cat_col=df.select_dtypes(include=["object"]).columns.tolist()
num_col=df.select_dtypes(include=["number"]).columns.tolist()

# %% [markdown]
# ## Categorical Columns

# %%
cat_col
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %% [markdown]
# ## Numerical Column

# %%
num_col
# Out:
# ['release_year']

# %% [markdown]
# # Univariate Analysis

# %%
df["show_id"].unique()
# Out:
# array(['s1', 's2', 's3', ..., 's8805', 's8806', 's8807'], dtype=object)

# %%
df["show_id"].value_counts()
# Out:
# show_id
# s8807    1
# s1       1
# s2       1
# s3       1
# s4       1
#         ..
# s12      1
# s11      1
# s10      1
# s9       1
# s8       1
# Name: count, Length: 8807, dtype: int64

# %%
len(df["show_id"].unique())
# Out:
# 8807

# %% [markdown]
# ### Key Insights
# - Number of rows = length of unique values of show_id
# - It is used to define each rows uniquely
# - it is not a important columns

# %%
df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
df["type"].value_counts()
# Out:
# type
# Movie      6131
# TV Show    2676
# Name: count, dtype: int64

# %% [markdown]
# ### Key Insights
# - type has only two categories: 'Movie' and  'TV Show'.
# - Movie--->  6131
# - TV Show  --->  2676
# - Movie is higher in number than TV Show.

# %%
df['title'].unique()
# Out:
# array(['Dick Johnson Is Dead', 'Blood & Water', 'Ganglands', ...,
#        'Zombieland', 'Zoom', 'Zubaan'], dtype=object)

# %%
len(df['title'].unique())
# Out:
# 8807

# %%
df['director'].unique()
# Out:
# array(['Kirsten Johnson', nan, 'Julien Leclercq', ..., 'Majid Al Ansari',
#        'Peter Hewitt', 'Mozez Singh'], dtype=object)

# %%
len(df['director'].unique())
# Out:
# 4529

# %%
df['director'].value_counts()
# Out:
# director
# Rajiv Chilaka              19
# Raúl Campos, Jan Suter     18
# Suhas Kadav                16
# Marcus Raboy               16
# Jay Karas                  14
#                            ..
# James Brown                 1
# Ivona Juka                  1
# Mu Chu                      1
# Chandra Prakash Dwivedi     1
# Majid Al Ansari             1
# Name: count, Length: 4528, dtype: int64

# %% [markdown]
# ### Key Insights
# - Rajiv Chilaka Directed 19 movies which is the highest.
# - He is experienced among all the directors.

# %%
df['cast']
# Out:
# 0                                                     NaN
# 1       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...
# 2       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...
# 3                                                     NaN
# 4       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...
#                               ...
# 8802    Mark Ruffalo, Jake Gyllenhaal, Robert Downey J...
# 8803                                                  NaN
# 8804    Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# 8805    Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 8806    Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# Name: cast, Length: 8807, dtype: object

# %%
cat_col
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %%
df["country"].unique()
# Out:
# array(['United States', 'South Africa', nan, 'India',
#        'United States, Ghana, Burkina Faso, United Kingdom, Germany, Ethiopia',
#        'United Kingdom', 'Germany, Czech Republic', 'Mexico', 'Turkey',
#        'Australia', 'United States, India, France', 'Finland',
#        'China, Canada, United States',
#        'South Africa, United States, Japan', 'Nigeria', 'Japan',
#        'Spain, United States', 'France', 'Belgium',
#        'United Kingdom, United States', 'United States, United Kingdom',
#        'France, United States', 'South Korea', 'Spain',
#        'United States, Singapore', 'United Kingdom, Australia, France',
#        'United Kingdom, Australia, France, United States',
#        'United States, Canada', 'Germany, United States',
#        'South Africa, United States', 'United States, Mexico',
#        'United States, Italy, France, Japan',
#        'United States, Italy, Romania, United Kingdom',
#        'Australia, United States', 'Argentina, Venezuela',
# ...

# %%
len(df["country"].unique())
# Out:
# 749

# %%
df["country"].value_counts()
# Out:
# country
# United States                                                      2818
# India                                                               972
# United Kingdom                                                      419
# Japan                                                               245
# South Korea                                                         199
#                                                                    ...
# Mexico, United States, Spain, Colombia                                1
# Canada, Norway                                                        1
# Finland, Germany, Belgium                                             1
# Argentina, United States, Mexico                                      1
# United Kingdom, United States, Germany, Denmark, Belgium, Japan       1
# Name: count, Length: 748, dtype: int64

# %% [markdown]
# ### Key Insights
# - United State is the biggest market.
# - India is the second biggest market.
# - United Kingdom is the third biggest market.

# %%
df["date_added"]
# Out:
# 0       September 25, 2021
# 1       September 24, 2021
# 2       September 24, 2021
# 3       September 24, 2021
# 4       September 24, 2021
#                ...
# 8802     November 20, 2019
# 8803          July 1, 2019
# 8804      November 1, 2019
# 8805      January 11, 2020
# 8806         March 2, 2019
# Name: date_added, Length: 8807, dtype: object

# %%
df["rating"]
# Out:
# 0       PG-13
# 1       TV-MA
# 2       TV-MA
# 3       TV-MA
# 4       TV-MA
#         ...
# 8802        R
# 8803    TV-Y7
# 8804        R
# 8805       PG
# 8806    TV-14
# Name: rating, Length: 8807, dtype: object

# %%
df["rating"].unique()
# Out:
# array(['PG-13', 'TV-MA', 'PG', 'TV-14', 'TV-PG', 'TV-Y', 'TV-Y7', 'R',
#        'TV-G', 'G', 'NC-17', '74 min', '84 min', '66 min', 'NR', nan,
#        'TV-Y7-FV', 'UR'], dtype=object)

# %%
len(df["rating"].unique())
# Out:
# 18

# %%
df["rating"].value_counts()
# Out:
# rating
# TV-MA       3207
# TV-14       2160
# TV-PG        863
# R            799
# PG-13        490
# TV-Y7        334
# TV-Y         307
# PG           287
# TV-G         220
# NR            80
# G             41
# TV-Y7-FV       6
# NC-17          3
# UR             3
# 74 min         1
# 84 min         1
# 66 min         1
# Name: count, dtype: int64

# %% [markdown]
# ### Key Insights
# - rating has 18 unique values
# - TV-MA has more number movies (Mature Audience)-->3207
# - TV-14 is at second position.

# %%
df['duration']
# Out:
# 0          90 min
# 1       2 Seasons
# 2        1 Season
# 3        1 Season
# 4       2 Seasons
#           ...
# 8802      158 min
# 8803    2 Seasons
# 8804       88 min
# 8805       88 min
# 8806      111 min
# Name: duration, Length: 8807, dtype: object

# %%
df['duration'].value_counts()
# Out:
# duration
# 1 Season     1793
# 2 Seasons     425
# 3 Seasons     199
# 90 min        152
# 97 min        146
#              ...
# 228 min         1
# 18 min          1
# 205 min         1
# 201 min         1
# 191 min         1
# Name: count, Length: 220, dtype: int64

# %% [markdown]
# ### Key Insights
# - Season 1 has highest duration.
# - Season 2 has 2nd highest while Season 3 has 3rd highest.

# %%
df['listed_in']
# Out:
# 0                                           Documentaries
# 1         International TV Shows, TV Dramas, TV Mysteries
# 2       Crime TV Shows, International TV Shows, TV Act...
# 3                                  Docuseries, Reality TV
# 4       International TV Shows, Romantic TV Shows, TV ...
#                               ...
# 8802                       Cult Movies, Dramas, Thrillers
# 8803               Kids' TV, Korean TV Shows, TV Comedies
# 8804                              Comedies, Horror Movies
# 8805                   Children & Family Movies, Comedies
# 8806       Dramas, International Movies, Music & Musicals
# Name: listed_in, Length: 8807, dtype: object

# %%
df['listed_in'].str.split()
# Out:
# 0                                         [Documentaries]
# 1       [International, TV, Shows,, TV, Dramas,, TV, M...
# 2       [Crime, TV, Shows,, International, TV, Shows,,...
# 3                              [Docuseries,, Reality, TV]
# 4       [International, TV, Shows,, Romantic, TV, Show...
#                               ...
# 8802                  [Cult, Movies,, Dramas,, Thrillers]
# 8803       [Kids', TV,, Korean, TV, Shows,, TV, Comedies]
# 8804                          [Comedies,, Horror, Movies]
# 8805             [Children, &, Family, Movies,, Comedies]
# 8806    [Dramas,, International, Movies,, Music, &, Mu...
# Name: listed_in, Length: 8807, dtype: object

# %%
all_genre=[]
for rows in df['listed_in'].str.split(","):
    all_genre.extend(rows)

# %%
genre=pd.Series(all_genre)
genre.value_counts()
# Out:
#  International Movies        2624
# Dramas                       1600
# Comedies                     1210
# Action & Adventure            859
# Documentaries                 829
#                              ...
# Romantic Movies                 3
# Spanish-Language TV Shows       2
# LGBTQ Movies                    1
# TV Sci-Fi & Fantasy             1
# Sports Movies                   1
# Name: count, Length: 73, dtype: int64

# %%
list(set(all_genre))
# Out:
# [' Romantic Movies',
#  ' TV Comedies',
#  ' Horror Movies',
#  'Anime Series',
#  'Documentaries',
#  ' TV Sci-Fi & Fantasy',
#  'Reality TV',
#  'TV Action & Adventure',
#  'Movies',
#  ' Stand-Up Comedy',
#  'Sci-Fi & Fantasy',
#  'Anime Features',
#  'TV Dramas',
#  ' Teen TV Shows',
#  ' TV Action & Adventure',
#  'Classic Movies',
#  ' Anime Features',
#  'Independent Movies',
#  'Docuseries',
#  'TV Shows',
#  'TV Sci-Fi & Fantasy',
#  ' Sci-Fi & Fantasy',
#  ' Korean TV Shows',
#  'Romantic Movies',
#  ' Classic Movies',
#  ' Sports Movies',
#  ' Dramas',
#  'Action & Adventure',
#  'TV Horror',
#  'International Movies',
#  'Stand-Up Comedy',
#  'Stand-Up Comedy & Talk Shows',
#  'TV Comedies',
#  ' Music & Musicals',
#  ' Science & Nature TV',
#  ' Cult Movies',
#  ' Independent Movies',
#  ' TV Horror',
#  'Music & Musicals',
#  ' TV Dramas',
#  ' Documentaries',
#  ' Comedies',
#  ' Thrillers',
#  'Romantic TV Shows',
#  ' LGBTQ Movies',
#  ' International TV Shows',
# ...

# %%
len(list(set(all_genre)))
# Out:
# 73

# %% [markdown]
# ### Key INsights
# - There are 73 genre in this netflix data
# - International Movies is the most popuar genre while dramas is 2nd popular genre
# - Comedy is the 3rd most poular genre

# %%
df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df[["date_added","release_year"]]
# Out:
#               date_added  release_year
# 0     September 25, 2021          2020
# 1     September 24, 2021          2021
# 2     September 24, 2021          2021
# 3     September 24, 2021          2021
# 4     September 24, 2021          2021
# ...                  ...           ...
# 8802   November 20, 2019          2007
# 8803        July 1, 2019          2018
# 8804    November 1, 2019          2009
# 8805    January 11, 2020          2006
# 8806       March 2, 2019          2015
#
# [8807 rows x 2 columns]

# %% [markdown]
# - ### **The most fundamental relationship between release year and date added is a strict chronological rule: a title's "date added" to Netflix can never happen before its original "release year."**

# %%
df['date_added']=pd.to_datetime(df['date_added'],format="mixed")

# %%
df['date_added']
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-24
# 4      2021-09-24
#           ...
# 8802   2019-11-20
# 8803   2019-07-01
# 8804   2019-11-01
# 8805   2020-01-11
# 8806   2019-03-02
# Name: date_added, Length: 8807, dtype: datetime64[ns]

# %%
df['date_added'].dt.year
# Out:
# 0       2021.0
# 1       2021.0
# 2       2021.0
# 3       2021.0
# 4       2021.0
#          ...
# 8802    2019.0
# 8803    2019.0
# 8804    2019.0
# 8805    2020.0
# 8806    2019.0
# Name: date_added, Length: 8807, dtype: float64

# %% [markdown]
# ### Valid Data

# %%
df[df['date_added'].dt.year>df["release_year"]].head()
# Out:
#    show_id     type                                              title  \
# 0       s1    Movie                               Dick Johnson Is Dead
# 7       s8    Movie                                            Sankofa
# 16     s17    Movie  Europe's Most Dangerous Man: Otto Skorzeny in ...
# 17     s18  TV Show                                    Falsa identidad
# 21     s22  TV Show                             Resurrection: Ertugrul
#
#                                          director  \
# 0                                 Kirsten Johnson
# 7                                    Haile Gerima
# 16  Pedro de Echave García, Pablo Azorín Williams
# 17                                            NaN
# 21                                            NaN
#
#                                                  cast  \
# 0                                                 NaN
# 7   Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# 16                                                NaN
# ...

# %% [markdown]
# ### Invalid Data

# %%
df[df['date_added'].dt.year<df["release_year"]].head()
# Out:
#      show_id     type               title director  \
# 1551   s1552  TV Show               Hilda      NaN
# 1696   s1697  TV Show        Polly Pocket      NaN
# 2920   s2921  TV Show       Love Is Blind      NaN
# 3168   s3169  TV Show        Fuller House      NaN
# 3287   s3288  TV Show  Maradona in Mexico      NaN
#
#                                                    cast  \
# 1551  Bella Ramsey, Ameerah Falzon-Ojo, Oliver Nelso...
# 1696  Emily Tennant, Shannon Chan-Kent, Kazumi Evans...
# 2920                        Nick Lachey, Vanessa Lachey
# 3168  Candace Cameron Bure, Jodie Sweetin, Andrea Ba...
# 3287                             Diego Armando Maradona
#
#                                     country date_added  release_year rating  \
# 1551  United Kingdom, Canada, United States 2020-12-14          2021  TV-Y7
# 1696         Canada, United States, Ireland 2020-11-15          2021   TV-Y
# 2920                          United States 2020-02-13          2021  TV-MA
# ...

# %%
df[df['date_added'].dt.year<df["release_year"]].shape
# Out:
# (14, 12)

# %% [markdown]
# ### Key Insights
# - There are 14 invalid data because they **date_added** is before is release date
# - So we need to remove these rows from the data
